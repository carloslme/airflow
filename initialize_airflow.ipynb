# %% [markdown]
# https://www.analyticsvidhya.com/blog/2020/11/getting-started-with-apache-airflow/

# %%
# !export AIRFLOW_HOME=~/airflow   # LINUX
#!set AIRFLOW_HOME=~/airflow  #WINDOWS

# %%
# !pip install apache-airflow
# Out:
# ...
#      |████████████████████████████████| 5.2 MB 4.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 79 kB 5.8 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 548 kB 21.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.8 MB 481 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 133 kB 5.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 111 kB 8.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 164 kB 6.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.3 MB 543 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 208 kB 12.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 76 kB 3.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 97 kB 3.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 86 kB 5.0 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 10.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.8 MB 939 kB/s eta 0:00:01
# ...

# %% [markdown]
# Database backend required to run workflows

# %%
# !airflow db init
# Out:
# DB: sqlite:////home/carlos/airflow/airflow.db
# [2021-07-19 18:11:19,971] {db.py:692} INFO - Creating tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Running upgrade  -> e3a246e0dc1, current schema
# INFO  [alembic.runtime.migration] Running upgrade e3a246e0dc1 -> 1507a7289a2f, create is_encrypted
# /home/carlos/anaconda3/lib/python3.8/site-packages/alembic/ddl/sqlite.py:43 UserWarning: Skipping unsupported ALTER for creation of implicit constraintPlease refer to the batch mode feature which allows for SQLite migrations using a copy-and-move strategy.
# INFO  [alembic.runtime.migration] Running upgrade 1507a7289a2f -> 13eb55f81627, maintain history for compatibility with earlier migrations
# INFO  [alembic.runtime.migration] Running upgrade 13eb55f81627 -> 338e90f54d61, More logging into task_instance
# ...

# %% [markdown]
# Start the webserver

# %%
# !airflow webserver -p 8080
# Out:
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ___  ___ |  / _  /   _  __/ _  / / /_/ /_ |/ |/ /
#  _/_/  |_/_/  /_/    /_/    /_/  \____/____/|__/
# [2021-07-19 18:12:02,710] {dagbag.py:496} INFO - Filling up the DagBag from /dev/null
# [2021-07-19 18:12:02,803] {manager.py:784} WARNING - No user yet created, use flask fab command to do it.
# Running the Gunicorn Server with:
# Workers: 4 sync
# Host: 0.0.0.0:8080
# Timeout: 120
# Logfiles: - -
# Access Logformat:
# ...
# [2021-07-19 18:12:05 -0500] [2010] [INFO] Starting gunicorn 20.1.0
# [2021-07-19 18:12:05 -0500] [2010] [INFO] Listening at: http://0.0.0.0:8080 (2010)
# [2021-07-19 18:12:05 -0500] [2010] [INFO] Using worker: sync
# [2021-07-19 18:12:05 -0500] [2012] [INFO] Booting worker with pid: 2012
# [2021-07-19 18:12:05 -0500] [2013] [INFO] Booting worker with pid: 2013
# ...

# %% [markdown]
# Start the airflow scheduler

# %%
# !airflow scheduler
# Out:
#   ____________       _____________
#  ____    |__( )_________  __/__  /________      __
# ____  /| |_  /__  ___/_  /_ __  /_  __ \_ | /| / /
# ___  ___ |  / _  /   _  __/ _  / / /_/ /_ |/ |/ /
#  _/_/  |_/_/  /_/    /_/    /_/  \____/____/|__/
#  * Serving Flask app "airflow.utils.serve_logs" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
# [2021-07-19 18:14:22,131] {_internal.py:113} INFO -  * Running on http://0.0.0.0:8793/ (Press CTRL+C to quit)
# [2021-07-19 18:14:22,138] {scheduler_job.py:1266} INFO - Starting the scheduler
# [2021-07-19 18:14:22,138] {scheduler_job.py:1271} INFO - Processing each file at most -1 times
# [2021-07-19 18:14:22,142] {dag_processing.py:254} INFO - Launched DagFileProcessorManager with pid: 2019
# [2021-07-19 18:14:22,143] {scheduler_job.py:1835} INFO - Resetting orphaned tasks for active dag runs
# ...

# %% [markdown]
# Create new user

# %%
# !airflow users  create --role Admin --username admin --email admin --firstname admin --lastname admin --password admin
# Out:
# admin already exist in the db
